# %%
# Imports
from models import *
from data import *
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
# Get the dataset
dataset = Dataset.get_dataset('multi_eurlex')

# %%
# Initialize the model
data, label_options = dataset.get_data('en')
model = Model.get_model('bart', label_options, multi_class=True)
# Out:
# Generating train split:   0%|          | 0/55000 [00:00<?, ? examples/s]
# KeyboardInterrupt

# %%
# Get the predicted labels
predicted_labels = model.predict(data)
true_labels = model.get_true_labels(data)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Get the predicted labels
# ----> 2 predicted_labels = model.predict(data)
#       3 true_labels = model.get_true_labels(data)
#
# File ~\Multilingual-Evaluation-of-Generative-AI\Pipeline\models.py:89, in Bart.predict(self, dataset)
#      87 for item in dataset:
#      88     text = item['text']
# ---> 89     predicted_labels.append(self.classify_text(text))
#      90 return predicted_labels
#
# File ~\Multilingual-Evaluation-of-Generative-AI\Pipeline\models.py:76, in Bart.classify_text(self, text)
#      73 print(type(text))
#      74 prompt = text + "<|endoftext|>" + ("Question: Which of the following labels apply?{', '.join(label_options)} "
#      75                                    "Answer:")
# ---> 76 generated_text = self.generate_text(prompt)
#      77 prediction = self.extract_labels_from_generated_text(generated_text, self.label_options)
#      78 predicted_labels_indexed = self.map_labels_to_indices(prediction, self.label_options)
#
# File ~\Multilingual-Evaluation-of-Generative-AI\Pipeline\models.py:64, in Bart.generate_text(self, prompt)
#      62 def generate_text(self, prompt):
#      63     inputs = self.tokenizer(prompt, return_tensors="pt", truncation=True)
# ---> 64     outputs = self.model.generate(**inputs, max_length=100, num_return_sequences=1)
#      65     generated_text = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
#      66     return generated_text
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\generation\utils.py:2063, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2055     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2056         input_ids=input_ids,
#    2057         expand_size=generation_config.num_beams,
#    2058         is_encoder_decoder=self.config.is_encoder_decoder,
#    2059         **model_kwargs,
#    2060     )
#    2062     # 14. run beam sample
# -> 2063     result = self._beam_search(
#    2064         input_ids,
#    2065         beam_scorer,
#    2066         logits_processor=prepared_logits_processor,
#    2067         logits_warper=prepared_logits_warper,
#    2068         stopping_criteria=prepared_stopping_criteria,
#    2069         generation_config=generation_config,
#    2070         synced_gpus=synced_gpus,
#    2071         **model_kwargs,
#    2072     )
#    2074 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2075     # 11. prepare beam search scorer
#    2076     beam_scorer = BeamSearchScorer(
#    2077         batch_size=batch_size,
#    2078         num_beams=generation_config.num_beams,
#    (...)
#    2084         max_length=generation_config.max_length,
#    2085     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\generation\utils.py:3238, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, logits_warper, **model_kwargs)
#    3235     outputs = stack_model_outputs(outputs_per_sub_batch)
#    3237 else:  # Unchanged original behavior
# -> 3238     outputs = self(**model_inputs, return_dict=True)
#    3240 if synced_gpus and this_peer_finished:
#    3241     cur_len = cur_len + 1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\bart\modeling_bart.py:1641, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1636     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1637         decoder_input_ids = shift_tokens_right(
#    1638             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1639         )
# -> 1641 outputs = self.model(
#    1642     input_ids,
#    1643     attention_mask=attention_mask,
#    1644     decoder_input_ids=decoder_input_ids,
#    1645     encoder_outputs=encoder_outputs,
#    1646     decoder_attention_mask=decoder_attention_mask,
#    1647     head_mask=head_mask,
#    1648     decoder_head_mask=decoder_head_mask,
#    1649     cross_attn_head_mask=cross_attn_head_mask,
#    1650     past_key_values=past_key_values,
#    1651     inputs_embeds=inputs_embeds,
#    1652     decoder_inputs_embeds=decoder_inputs_embeds,
#    1653     use_cache=use_cache,
#    1654     output_attentions=output_attentions,
#    1655     output_hidden_states=output_hidden_states,
#    1656     return_dict=return_dict,
#    1657 )
#    1659 lm_logits = self.lm_head(outputs[0])
#    1660 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\bart\modeling_bart.py:1527, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1520     encoder_outputs = BaseModelOutput(
#    1521         last_hidden_state=encoder_outputs[0],
#    1522         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1523         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1524     )
#    1526 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1527 decoder_outputs = self.decoder(
#    1528     input_ids=decoder_input_ids,
#    1529     attention_mask=decoder_attention_mask,
#    1530     encoder_hidden_states=encoder_outputs[0],
#    1531     encoder_attention_mask=attention_mask,
#    1532     head_mask=decoder_head_mask,
#    1533     cross_attn_head_mask=cross_attn_head_mask,
#    1534     past_key_values=past_key_values,
#    1535     inputs_embeds=decoder_inputs_embeds,
#    1536     use_cache=use_cache,
#    1537     output_attentions=output_attentions,
#    1538     output_hidden_states=output_hidden_states,
#    1539     return_dict=return_dict,
#    1540 )
#    1542 if not return_dict:
#    1543     return decoder_outputs + encoder_outputs
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\bart\modeling_bart.py:1379, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1366     layer_outputs = self._gradient_checkpointing_func(
#    1367         decoder_layer.__call__,
#    1368         hidden_states,
#    (...)
#    1376         use_cache,
#    1377     )
#    1378 else:
# -> 1379     layer_outputs = decoder_layer(
#    1380         hidden_states,
#    1381         attention_mask=attention_mask,
#    1382         encoder_hidden_states=encoder_hidden_states,
#    1383         encoder_attention_mask=encoder_attention_mask,
#    1384         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1385         cross_attn_layer_head_mask=(
#    1386             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1387         ),
#    1388         past_key_value=past_key_value,
#    1389         output_attentions=output_attentions,
#    1390         use_cache=use_cache,
#    1391     )
#    1392 hidden_states = layer_outputs[0]
#    1394 if use_cache:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\bart\modeling_bart.py:665, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     663 self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
#     664 # add present self-attn cache to positions 1,2 of present_key_value tuple
# --> 665 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     666     hidden_states=hidden_states,
#     667     past_key_value=self_attn_past_key_value,
#     668     attention_mask=attention_mask,
#     669     layer_head_mask=layer_head_mask,
#     670     output_attentions=output_attentions,
#     671 )
#     672 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     673 hidden_states = residual + hidden_states
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\bart\modeling_bart.py:469, in BartSdpaAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     466 elif past_key_value is not None:
#     467     # reuse k, v, self_attention
#     468     key_states = self._shape(self.k_proj(hidden_states), -1, bsz)
# --> 469     value_states = self._shape(self.v_proj(hidden_states), -1, bsz)
#     470     key_states = torch.cat([past_key_value[0], key_states], dim=2)
#     471     value_states = torch.cat([past_key_value[1], value_states], dim=2)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Evaluate the performance
# Flatten the lists of lists into single lists
flat_predicted_labels = [label for sublist in predicted_labels for label in sublist]
flat_true_labels = [label for sublist in true_labels for label in sublist]

# Accuracy
accuracy = accuracy_score(flat_true_labels, flat_predicted_labels)

# Precision, Recall, F1 Score (for multiclass classification, use 'macro', 'micro', or 'weighted' averaging)
precision = precision_score(flat_true_labels, flat_predicted_labels, average='macro')
recall = recall_score(flat_true_labels, flat_predicted_labels, average='macro')
f1 = f1_score(flat_true_labels, flat_predicted_labels, average='macro')

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Precision (Macro): {precision}")
print(f"Recall (Macro): {recall}")
print(f"F1 Score (Macro): {f1}")
